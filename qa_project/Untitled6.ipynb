# %%
#for API key update

with open("/Users/krishna/Desktop/Research/qa_project/.env", "w") as f:
    f.write("OPENAI_API_KEY=paste-your-openai-key-here\n")
print("Done!")

# %%
import os
os.chdir("/Users/krishna/Desktop/Research/qa_project")
print(os.getcwd())  # confirm you're in the right folder
# Out:
# /Users/krishna/Desktop/Research/qa_project

# %%
import sys
sys.argv = ['main.py', '--conditions', 'cot_only', 'rag_cot', 'rag_cot_selfverify']

exec(open('main.py').read())
# Out:
# [INFO]  Loading training dataset from /Users/krishna/Desktop/Research/qa_project/datasets/qa_train_dataset.csv
# [OK]    Training dataset loaded: 100 questions
#
# ============================================================
#   Pipeline: TRAIN split  (100 questions)
# ============================================================
# [INFO]  Dataset composition:
# error_type         knowledge  none  reasoning  total
# source_dataset
# HotpotQA                   2     3         26     31
# Natural Questions         11    25          0     36
# TriviaQA                   5    28          0     33
#
# [INFO]  LLM initialised in LIVE mode → gpt-4-turbo
# [INFO]  Loading DPR question encoder...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/facebook-dpr-question_encoder-single-nq-base
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INFO]  Loading FAISS index...
# [INFO]  Retriever ready — 100,000 passages indexed.
#
# ============================================================
#   Running Experimental Conditions
# ============================================================
# [INFO]  Condition 1/5 → Closed-Book
# Closed-Book: 100%|████████████████████████████| 100/100 [02:13<00:00,  1.34s/it]
# [INFO]    [Closed-Book]  EM = 76.0%   F1 = 82.0%
# [INFO]  Condition 2/5 → RAG Only
# RAG-Only: 100%|███████████████████████████████| 100/100 [03:13<00:00,  1.94s/it]
# [INFO]    [RAG Only]  EM = 71.0%   F1 = 77.4%
# [INFO]  Condition 3/5 → CoT Only
# CoT-Only: 100%|███████████████████████████████| 100/100 [18:36<00:00, 11.17s/it]
# [INFO]    [CoT Only]  EM = 46.0%   F1 = 61.7%
# [INFO]  Condition 4/5 → RAG + CoT
# RAG+CoT: 100%|████████████████████████████████| 100/100 [15:06<00:00,  9.07s/it]
# [INFO]    [RAG + CoT]  EM = 48.0%   F1 = 62.3%
# [INFO]  Condition 5/5 → RAG + CoT + Self-Verify
# Self-Verify: 100%|████████████████████████████| 100/100 [19:19<00:00, 11.60s/it]
# [INFO]    [RAG + CoT + Self-Verify]  EM = 52.0%   F1 = 64.3%
#
# ============================================================
#   Error Classification
# ============================================================
# [INFO]  Auto-classifier agrees with manual annotations: 73.0%
# [INFO]  Error distribution by dataset:
#    source_dataset error_type  count  percentage
#          HotpotQA  knowledge      2         6.5
#          HotpotQA       none      3         9.7
#          HotpotQA  reasoning     26        83.9
# Natural Questions  knowledge     11        30.6
# Natural Questions       none     25        69.4
#          TriviaQA  knowledge      5        15.2
#          TriviaQA       none     28        84.8
#
# [INFO]  Sub-type breakdown:
# error_type     error_subtype  count
#       none              none     56
#  reasoning         multi_hop     26
#  knowledge    factual_recall     16
#  knowledge factual_precision      1
#  knowledge     outdated_info      1
#
# [INFO]  Hops vs error type:
# error_type         knowledge  none  reasoning  Total
# num_hops_required
# 1                         18    53          0     71
# 2                          0     3         25     28
# 3                          0     0          1      1
# Total                     18    56         26    100
#
#
# ============================================================
#   Accuracy Summary
# ============================================================
# dataset                  HotpotQA  Natural Questions  TriviaQA  Average
# condition
# Baseline (Closed-Book)       58.1               80.6      87.9     75.5
# CoT Only                     48.4               47.2      42.4     46.0
# RAG + CoT                    54.8               36.1      54.5     48.5
# RAG + CoT + Self-Verify      51.6               44.4      60.6     52.2
# RAG Only                     51.6               77.8      81.8     70.4
#
# [OK]    Results saved to /Users/krishna/Desktop/Research/qa_project/outputs/train/
#
# ============================================================
#   Generating Charts
# ============================================================
# [OK]      Chart saved: fig1_closed_vs_open.png
# [OK]      Chart saved: fig2_error_distribution_real.png
# [OK]      Chart saved: fig3_cot_impact.png
# [OK]      Chart saved: fig4_retrieval_curve.png
# [OK]      Chart saved: fig5_all_conditions.png
# [OK]      Chart saved: fig6_calibration.png
#
# ============================================================
#   Run Complete
# ============================================================
# [OK]      [train]  Mean EM across conditions = 58.5%
# [OK]    All outputs saved to: /Users/krishna/Desktop/Research/qa_project/outputs/

# %%
# %run main.py --mode live --split train
# Out:
# [INFO]  Mode overridden to: live
# [INFO]  Loading training dataset from /Users/krishna/Desktop/Research/qa_project/datasets/qa_train_dataset.csv
# [OK]    Training dataset loaded: 100 questions
#
# ============================================================
#   Pipeline: TRAIN split  (100 questions)
# ============================================================
# [INFO]  Dataset composition:
# error_type         knowledge  none  reasoning  total
# source_dataset
# HotpotQA                   2     3         26     31
# Natural Questions         11    25          0     36
# TriviaQA                   5    28          0     33
#
# [INFO]  LLM initialised in LIVE mode → gpt-4-turbo
# [INFO]  Loading DPR question encoder...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/facebook-dpr-question_encoder-single-nq-base
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INFO]  Loading FAISS index...
# [INFO]  Retriever ready — 100,000 passages indexed.
#
# ============================================================
#   Running Experimental Conditions
# ============================================================
# [INFO]  Condition 1/5 → Closed-Book
# Closed-Book: 100%|████████████████████████████| 100/100 [02:22<00:00,  1.43s/it]
# [INFO]    [Closed-Book]  EM = 76.0%   F1 = 82.1%
# [INFO]  Condition 2/5 → RAG Only
# RAG-Only: 100%|███████████████████████████████| 100/100 [02:54<00:00,  1.75s/it]
# [INFO]    [RAG Only]  EM = 71.0%   F1 = 77.4%
# [INFO]  Condition 3/5 → CoT Only
# CoT-Only:   7%|██▎                              | 7/100 [01:28<18:21, 11.85s/it]
